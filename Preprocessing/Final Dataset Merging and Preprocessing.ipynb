# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Activity Recognition/Datasets/testing/result_27.csv')
data
# Out:
#           Unnamed: 0  user_id                     timestamp  activity_id
# 0                  0       27  2018-12-11T16:46:05.707+0900            5
# 1                  1       27  2018-12-21T16:45:54.350+0900            5
# 2                  2       27  2018-12-21T10:38:58.230+0900            5
# 3                  3       27  2018-12-14T22:39:10.469+0900            5
# 4                  4       27  2018-12-07T15:43:06.481+0900            5
# ...              ...      ...                           ...          ...
# 12539426    12539426       27  2018-12-21T00:03:21.190+0900            5
# 12539427    12539427       27  2018-12-21T02:27:55.440+0900            5
# 12539428    12539428       27  2018-12-21T01:47:50.623+0900            5
# 12539429    12539429       27  2018-12-21T00:31:11.222+0900            5
# 12539430    12539430       27  2018-12-28T13:18:30.838+0900            5
#
# [12539431 rows x 4 columns]

# %%
# datafile = data
# datafile.drop(datafile[datafile['label']==1.0].index,inplace=True)
# datafile.drop(datafile[datafile['label']==2.0].index,inplace=True)
# datafile.drop(datafile[datafile['label']==3.0].index,inplace=True)
# datafile.drop(datafile[datafile['label']==4.0].index,inplace=True)
# datafile.drop(datafile[datafile['label']==5.0].index,inplace=True)
# datafile.drop(datafile[datafile['label']==6.0].index,inplace=True)
# datafile.drop(datafile[datafile['label']==7.0].index,inplace=True)
# datafile.drop(datafile[datafile['label']==9.0].index,inplace=True)
# datafile.drop(datafile[datafile['label']==10.0].index,inplace=True)
# datafile.drop(datafile[datafile['label']==12.0].index,inplace=True)
# datafile['label'].value_counts()

# %%
tmp = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Activity Recognition/Datasets/testing/result_29.csv')
data = data.append(tmp)
data
# Out:
#           Unnamed: 0  user_id                     timestamp  activity_id
# 0                  0       27  2018-12-11T16:46:05.707+0900            5
# 1                  1       27  2018-12-21T16:45:54.350+0900            5
# 2                  2       27  2018-12-21T10:38:58.230+0900            5
# 3                  3       27  2018-12-14T22:39:10.469+0900            5
# 4                  4       27  2018-12-07T15:43:06.481+0900            5
# ...              ...      ...                           ...          ...
# 15376303    15376303       29  2018-12-18T09:02:27.961+0900            5
# 15376304    15376304       29  2018-12-09T21:07:39.191+0900            5
# 15376305    15376305       29  2018-12-09T17:07:31.546+0900            5
# 15376306    15376306       29  2018-12-30T08:06:52.529+0900            5
# 15376307    15376307       29  2018-12-30T10:10:01.104+0900            5
#
# [27915739 rows x 4 columns]

# %%
tmp = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Activity Recognition/Datasets/testing/result_46.csv')
data = data.append(tmp)
data
# Out:
#           Unnamed: 0  user_id                     timestamp  activity_id
# 0                  0       27  2018-12-11T16:46:05.707+0900            5
# 1                  1       27  2018-12-21T16:45:54.350+0900            5
# 2                  2       27  2018-12-21T10:38:58.230+0900            5
# 3                  3       27  2018-12-14T22:39:10.469+0900            5
# 4                  4       27  2018-12-07T15:43:06.481+0900            5
# ...              ...      ...                           ...          ...
# 10206502    10206502       46  2018-12-10T01:44:55.275+0900            4
# 10206503    10206503       46  2018-12-10T01:09:18.973+0900            4
# 10206504    10206504       46  2018-12-10T01:32:52.384+0900            4
# 10206505    10206505       46  2018-12-10T01:12:23.812+0900            4
# 10206506    10206506       46  2018-12-10T01:37:59.423+0900            4
#
# [38122246 rows x 4 columns]

# %%
# tmp = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Activity Recognition/Datasets/processed_08.csv')
# data = data.append(tmp)
# data

# %%
# tmp = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Activity Recognition/Datasets/processed_18.csv')
# data = data.append(tmp)
# data

# %%
# tmp = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Activity Recognition/Datasets/processed_38.csv')
# data = data.append(tmp)
# data

# %%
# tmp = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Activity Recognition/Datasets/processed_51.csv')
# data = data.append(tmp)
# data

# %%
data['activity_id'].value_counts()
# Out:
# 5     24545135
# 3      7624370
# 4      3370971
# 12     2043060
# 7       356650
# 6       181920
# 1          110
# 9           20
# 10          10
# Name: activity_id, dtype: int64

# %%
# data['datetime'] = pd.to_datetime(data['datetime'])
# data = data.sort_values(by='datetime')
# data = data.reset_index(drop=True)
# data = data.sort_values(by='user_id')
# data = data.reset_index(drop=True)
# data

# %%
data.to_csv('/content/drive/My Drive/Colab Notebooks/Activity Recognition/Datasets/testing/test_result.csv')
